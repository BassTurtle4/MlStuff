# %%
import re
import math
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

from gensim.models import Word2Vec
from matplotlib.ticker import MaxNLocator

# %%
#### wordcloud
MAX_WORDS = 20
COLLOCATION = 1 #5
COLLOCATIONS = False

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
DATA = "/gdrive/MyDrive/Projects/CodeErrorsNLP/DATA/Errors_data.csv"

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv(DATA,header=None, names=['Error', 'Category','x','y'])
df = df.drop(['x','y'], axis=1)
df.head(10)
# Out:
#                                                Error  \
# 0                     Missing package-info java file
# 1  Utility classes should not have a public or de...
# 2                          Missing a Javadoc comment
# 3                     Parameter args should be final
# 4  File contains tab characters (this is the firs...
# 5                           Line has trailing spaces
# 6                           Line has trailing spaces
# 7            Line is longer than characters (found )
# 8                           Line has trailing spaces
# 9            Line is longer than characters (found )
#
#                        Category
# 0               JavadocPackage
# 1  HideUtilityClassConstructor
# 2         MissingJavadocMethod
# 3              FinalParameters
# 4             FileTabCharacter
# 5             RegexpSingleline
# 6             RegexpSingleline
# 7                   LineLength
# 8             RegexpSingleline
# 9                   LineLength

# %%
df.shape
# Out:
# (13993, 2)

# %%
print("Total unique categories:", df['Category'].nunique())
# Out:
# Total unique categories: 65

# %%
math.sqrt(df['Category'].nunique())
# Out:
# 8.06225774829855

# %%
df.iloc[182]['Error']
# Out:
# "'||' is not preceded with whitespace"

# %%
# df['Ctegory'].value_counts().plot.bar()

ax = df['Category'].value_counts().head(5).plot.bar()

ax.set_title('Top-5 Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Count')

plt.show()

# %%
# Remove whitespace around plot
fig = ax.get_figure()
fig.tight_layout()

# Save just the plot area to PDF
fig.savefig('/gdrive/MyDrive/Projects/CodeErrorsNLP/top5_category.pdf', bbox_inches='tight')

# %%
df['Category'].value_counts().head(5).plot.bar()
# Out:
# <Axes: >

# %%
df['Category'].value_counts().tail(5).plot.bar()
# Out:
# <Axes: >

# %%
# df['Ctegory'].value_counts().plot.bar()

ax = df['Error'].value_counts().head(5).plot.bar()

ax.set_title('Top-5 Errors')
ax.set_xlabel('Error')
ax.set_ylabel('Count')

plt.show()

# %%
# Remove whitespace around plot
fig = ax.get_figure()
# fig.tight_layout()

# Save just the plot area to PDF
fig.savefig('/gdrive/MyDrive/Projects/CodeErrorsNLP/top5_error.pdf', bbox_inches='tight')

# %% [markdown]
# ## Preprocessing the data

# %%
def preprocessing(text):

    # text = text.replace("/home/imhmede/workspace/hello.java:", "")
    # text = text.split()
    # text = [txt for i, txt in enumerate(text) if i!= 1]
    # print(text)
    # text = " ".join(text)
    # text = change_construct(text)
    # text = re.sub(r'[^\w\s\<\>]', '', text)
    # text = [txt.strip() for txt in text.split() if not txt.isdigit()]
    # text = " ".join(text)
    # text = text.replace('_', '')
    # text = text.lower()
    # text = text.replace("error", "<ERROR>")
    # text = text.replace("warn", "<WARN>")
    # # txt = re.sub(' +', ' ', text)
    # text = text.split()
    # text = " ".join(text)
    text = change_name_next(text)
    # text = change_def_next(text)
    text = change_class_next(text)
    text = change_method_next(text)
    text = change_brackets(text)
    text = change_isnot(text)
    text = change_construct(text)
    text = change_use_brackets(text)
    text = change_shouldbe(text)
    text = change_parameter_next(text)

    text = text.lower()
    return text

# %%
def change_name_next(text):
    l = text.split()
    j = ['<A_NAME>' if i>0 and l[i-1] in ["Name"] else l[i] for i in range(len(l))]
    return ' '.join(j)

# %%
def change_def_next(text):
    l = text.split()
    j = ['<A_FUNC_NAME>' if i>0 and l[i-1] in ["def"] else l[i] for i in range(len(l))]
    return ' '.join(j)

# %%
def change_class_next(text):
    l = text.split()
    j = ['<A_CLASS_NAME>' if i>0 and l[i-1] in ["Class"] else l[i] for i in range(len(l))]
    return ' '.join(j)

# %%
def change_parameter_next(text):
    l = text.split()
    j = ['<A_PARAMETER_NAME>' if i>0 and l[i-1] in ["Parameter"] else l[i] for i in range(len(l))]
    return ' '.join(j)

# %%
def change_method_next(text):
    l = text.split()
    j = ['<A_METHOD_NAME>' if i>0 and l[i-1] in ["method"] else l[i] for i in range(len(l))]
    return ' '.join(j)

# %%
def change_brackets(text):
    return re.sub(r"'[{()}]'", "<BRAKET>", text)

# %%
def change_construct(text):
    return re.sub(r"'[a-zA-Z]+'", "<CONSTRUCT>", text)

# %%
def change_isnot(text):
  if " is not" in text:
    new_text = re.sub(r'(^.*) is not', r'<OPERATOR> is not', text)
  else:
    new_text = text

  return new_text

# %%
def change_shouldbe(text):
  if " should be on" in text:
    new_text = re.sub(r'(^.*) should be on', r'<OPERATOR> should be on', text)
  else:
    new_text = text

  return new_text

# %%
def change_construct(text):
  if " construct must use" in text:
    new_text = re.sub(r'(^.*) construct must use', r'<OPERATOR> construct must use', text)
  else:
    new_text = text

  return new_text

# %%
def change_use_brackets(text):
  if "'{}'s" in text:
    new_text = re.sub(r"'{}'s", r"<BRACKET>", text)
  else:
    new_text = text

  return new_text

# %%
# n_text = preprocessing(content_list[160])
# print(n_text)

# %%
# id_ = 1002
id_ = 103
print(df.iloc[id_]['Error'])

n_text = preprocessing(df.iloc[id_]['Error'])
print(n_text)
# Out:
# '*' is not followed by whitespace
# <operator> is not followed by whitespace

# %% [markdown]
# ## Create a dataframe

# %%
df['clean'] = df['Error'].apply(preprocessing)

# %%
df.head()
# Out:
#                                                Error  \
# 0                     Missing package-info java file
# 1  Utility classes should not have a public or de...
# 2                          Missing a Javadoc comment
# 3                     Parameter args should be final
# 4  File contains tab characters (this is the firs...
#
#                        Category  \
# 0               JavadocPackage
# 1  HideUtilityClassConstructor
# 2         MissingJavadocMethod
# 3              FinalParameters
# 4             FileTabCharacter
#
#                                                clean
# 0                     missing package-info java file
# 1  utility classes should not have a public or de...
# 2                          missing a javadoc comment
# 3       parameter <a_parameter_name> should be final
# 4  file contains tab characters (this is the firs...

# %%
df.iloc[1]["clean"]
# Out:
# 'utility classes should not have a public or default constructor'

# %%
df.iloc[114]["clean"]
# Out:
# '<operator> is not preceded with whitespace'

# %%
df.iloc[114]["clean"]
# Out:
# '<operator> is not preceded with whitespace'

# %% [markdown]
# ## Create a Word Cloud

# %%
all_text = []
def get_all_text(text):
    all_text.append(text)

df["clean"].apply(get_all_text)
text = "\n".join(all_text)
# print(text)

# wordcloud = WordCloud(background_color="white").generate(text)

#Create the wordcloud object
wordcloud = WordCloud(collocations= False,
                        background_color="white",
                        collocation_threshold = 100,
                        max_words = 10,
                        relative_scaling = 1).generate(text)
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')
plt.title("Word Cloud for Error Descriptions")
plt.savefig("/gdrive/MyDrive/Projects/CodeErrorsNLP/wordcloud.pdf", bbox_inches='tight')
plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(text)

print(frequencies)
# Out:
# {'missing': 890, 'package': 395, 'info': 390, 'java': 453, 'file': 650, 'utility': 378, 'classes': 378, 'public': 378, 'default': 380, 'constructor': 378, 'javadoc': 713, 'comment': 691, 'parameter': 1080, 'a_parameter_name': 1080, 'final': 1080, 'contains': 370, 'tab': 72, 'characters': 1582, 'first': 279, 'instance': 72, 'line': 4668, 'trailing': 1624, 'spaces': 1624, 'longer': 1510, 'found': 1510, 'magic': 711, 'number': 711, 'operator': 6039, 'preceded': 1853, 'whitespace': 4656, 'previous': 1193, 'followed': 2803, 'end': 394, 'newline': 187, 'array': 49, 'illegal': 47, 'position': 47, 'construct': 131, 'must': 508, 'use': 131, 'bracket': 178, 'placed': 191, 'wrong': 191, 'location': 191, 'next': 298, 'part': 298, 'multi': 298, 'block': 600, 'statement': 341, 'one': 300, 'directly': 298, 'multiple': 298, 'try': 298, 'catch': 298, 'finally': 298, 'unused': 92, 'import': 65, 'io': 12, 'name': 317, 'a_name': 316, 'match': 315, 'pattern': 315, 'za': 627, 'z': 315, "int'": 26, 'sentence': 207, 'period': 207, 'expected': 93, 'param': 165, 'tag': 213, "list'": 2, 'return': 42, 'present': 39, 'description': 39, 'braket': 229, 'conditional': 45, 'logic': 45, 'removed': 45, 'expression': 35, 'simplified': 35, 'variable': 61, 'declaration': 36, 'using': 41, 'form': 41, 'avoided': 43, "variables'": 2, "variable'": 2, "scanner'": 1, "array'": 9, "args'": 26, "a'": 5, 'redundant': 5, 'lang': 18, 'math': 11, "x'": 12, "y'": 12, "z'": 12, "input'": 10, 'private': 24, 'accessor': 24, 'definition': 3, 'per': 1, 'allowed': 1, 'util': 35, 'javax': 6, 'swing': 4, 'column': 25, 'break': 20, 'new': 17, 'class': 22, 'a_class_name': 21, 'looks': 21, 'designed': 21, 'extension': 21, 'subclassed': 21, 'method': 46, 'a_method_name': 26, 'explains': 21, 'safely': 21, "double'": 16, "rand'": 1, 'inner': 2, 'assignments': 2, "values'": 1, "arr'": 12, "b'": 4, "length'": 2, "tempformat'": 1, "temp'": 1, "allthesame'": 1, 'alone': 5, 'empty': 6, "sequencereader'": 1, 'z_': 3, 'w': 3, 'abs': 1, 'input': 1, "order'": 1, "success'": 1, "failure'": 1, "method_stack_index'": 2, "firstarray'": 2, "secondarray'": 2, 'duplicate': 3, "random'": 1, "teachersexample'": 1, "three'": 4, "str'": 5, 'stream': 2, "grademap'": 1, "grades'": 1, "pass_status'": 1, "fail_status'": 1, "inta'": 2, "intb'": 2, "string'": 8, 'inputmismatchexception': 1, 'least': 1, "n'": 2, "filename'": 1, 'scanner': 4, 'evenindex': 1, 'time': 1, "time'": 2, 'hides': 4, 'field': 4, "timedifference'": 1, 'avoid': 4, 'nested': 4, 'unknown': 5, "date'": 2, "return'": 3, "firstnumber'": 3, "secondnumber'": 3, "thirdnumber'": 3, "result'": 3, "first'": 2, "second'": 2, 'without': 3, 'corresponding': 1, 'hashcode': 1, 'model': 2, 'element': 1, 'variableelement': 1, 'org': 1, 'wc': 1, 'dom': 1, 'range': 2, 'random': 1, 'filenotfoundexception': 1, "assignemnt'": 1, "author'": 1, "purpose'": 1, 'equal': 2, 'enclosing': 1, 'switch': 2, 'clause': 2, 'elementscanner': 1, "laba'": 1}

# %% [markdown]
# ## Using Doc2Vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
DIMENSIONS = 64
WINDOW = 5

# %%
all_texts = df['clean'].tolist()
all_texts = [text.split() for text in all_texts]
print(len(all_texts))
# Out:
# 13993

# %%
print(all_texts[:2])
print(all_texts[-2:])
# Out:
# [['missing', 'package-info', 'java', 'file'], ['utility', 'classes', 'should', 'not', 'have', 'a', 'public', 'or', 'default', 'constructor']]
# [['line', 'has', 'trailing', 'spaces'], ['line', 'has', 'trailing', 'spaces']]

# %%
df["textList"] = all_texts

# %%
df
# Out:
#                                                    Error  \
# 0                         Missing package-info java file
# 1      Utility classes should not have a public or de...
# 2                              Missing a Javadoc comment
# 3                         Parameter args should be final
# 4      File contains tab characters (this is the firs...
# ...                                                  ...
# 13988                     Parameter args should be final
# 13989                           Line has trailing spaces
# 13990                           Line has trailing spaces
# 13991                           Line has trailing spaces
# 13992                           Line has trailing spaces
#
#                            Category  \
# 0                   JavadocPackage
# 1      HideUtilityClassConstructor
# 2             MissingJavadocMethod
# 3                  FinalParameters
# 4                 FileTabCharacter
# ...                             ...
# 13988              FinalParameters
# 13989             RegexpSingleline
# 13990             RegexpSingleline
# 13991             RegexpSingleline
# 13992             RegexpSingleline
#
#                                                    clean  \
# 0                         missing package-info java file
# 1      utility classes should not have a public or de...
# 2                              missing a javadoc comment
# 3           parameter <a_parameter_name> should be final
# 4      file contains tab characters (this is the firs...
# ...                                                  ...
# 13988       parameter <a_parameter_name> should be final
# 13989                           line has trailing spaces
# 13990                           line has trailing spaces
# 13991                           line has trailing spaces
# 13992                           line has trailing spaces
#
#                                                 textList
# 0                    [missing, package-info, java, file]
# 1      [utility, classes, should, not, have, a, publi...
# 2                         [missing, a, javadoc, comment]
# 3      [parameter, <a_parameter_name>, should, be, fi...
# 4      [file, contains, tab, characters, (this, is, t...
# ...                                                  ...
# 13988  [parameter, <a_parameter_name>, should, be, fi...
# 13989                      [line, has, trailing, spaces]
# 13990                      [line, has, trailing, spaces]
# 13991                      [line, has, trailing, spaces]
# 13992                      [line, has, trailing, spaces]
#
# [13993 rows x 4 columns]

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(all_texts)]

# %% [markdown]
# ### Get embeddings for multiple dimensions

# %%
dims = [16, 32, 64, 128, 256, 512]

for dim in dims:
    print(f"Doc2Vec for {dim} dimensions")
    # Init model
    doc2_vec_model = Doc2Vec(documents, vector_size=dim, epochs=20, window=WINDOW, min_count=5, seed=0)

    # Get vectors
    all_d2v_vecs = [doc2_vec_model.dv[i] for i in range(len(doc2_vec_model.dv))]

    # Add to df
    col_name = 'embedding_' + str(dim)
    df[col_name] = all_d2v_vecs
# Out:
# Doc2Vec for 16 dimensions
# Doc2Vec for 32 dimensions
# Doc2Vec for 64 dimensions
# Doc2Vec for 128 dimensions
# Doc2Vec for 256 dimensions
# Doc2Vec for 512 dimensions

# %%
df.head()
# Out:
#                                                Error  \
# 0                     Missing package-info java file
# 1  Utility classes should not have a public or de...
# 2                          Missing a Javadoc comment
# 3                     Parameter args should be final
# 4  File contains tab characters (this is the firs...
#
#                        Category  \
# 0               JavadocPackage
# 1  HideUtilityClassConstructor
# 2         MissingJavadocMethod
# 3              FinalParameters
# 4             FileTabCharacter
#
#                                                clean  \
# 0                     missing package-info java file
# 1  utility classes should not have a public or de...
# 2                          missing a javadoc comment
# 3       parameter <a_parameter_name> should be final
# 4  file contains tab characters (this is the firs...
#
#                                             textList  \
# 0                [missing, package-info, java, file]
# 1  [utility, classes, should, not, have, a, publi...
# 2                     [missing, a, javadoc, comment]
# 3  [parameter, <a_parameter_name>, should, be, fi...
# 4  [file, contains, tab, characters, (this, is, t...
#
#                                         embedding_16  \
# 0  [-0.015551005, 0.033605706, 0.024641672, -0.06...
# 1  [-0.1368318, 0.038364783, -0.036842555, -0.083...
# 2  [0.031338092, 0.14706026, -0.11331174, 0.04538...
# 3  [0.055871285, -0.046852883, -0.018312456, -0.1...
# 4  [0.06927245, 0.03268087, -0.068136595, 0.05919...
#
#                                         embedding_32  \
# 0  [0.11356431, 0.12167054, 0.046877578, 0.002169...
# 1  [0.05528406, 0.085993946, 0.02528275, 0.040453...
# 2  [0.18168919, 0.13130507, 0.037680723, 0.062324...
# 3  [0.1184343, 0.10719438, 0.04544073, 0.07976507...
# 4  [-0.006012668, 0.08069822, -0.06056278, 0.0127...
#
#                                         embedding_64  \
# 0  [0.048794147, -0.009825103, 0.04454054, -0.049...
# 1  [-0.0146215875, -0.06162069, 0.0002887169, 0.0...
# 2  [0.070900455, -0.011056697, 0.04327284, -0.039...
# 3  [0.027767941, 0.013156969, 0.0653381, -0.07377...
# 4  [-0.012465264, -0.02325621, -0.030042764, 0.03...
#
#                                        embedding_128  \
# 0  [0.042123422, -0.0325226, 0.0192305, 0.0111013...
# 1  [0.016139103, -0.013041689, 0.028586313, -0.01...
# 2  [0.018523373, -0.008445454, 0.0015263191, 0.02...
# 3  [0.05428207, -0.044264376, -0.0142417755, 0.03...
# 4  [0.038426444, -0.031036995, 0.007968803, 0.011...
#
#                                        embedding_256  \
# 0  [0.015540451, -0.0077465456, -0.024257822, -0....
# 1  [-0.0023854873, -0.017778205, -0.017936917, 0....
# 2  [0.041183252, -0.0039972975, -0.031711332, -0....
# 3  [-0.0069575994, -0.0017535925, -0.023125423, 0...
# 4  [0.019988338, 0.015296029, 0.019334216, -0.018...
#
#                                        embedding_512
# 0  [0.0032496152, 0.01017696, -0.005061691, 0.001...
# 1  [0.00023381141, -0.0034163457, -0.008104014, 0...
# 2  [0.0015146778, 0.008322123, -0.017599704, -0.0...
# 3  [0.014764239, 0.0073536434, -0.007747488, 0.00...
# 4  [0.025814686, 0.01866307, -0.017561177, -0.000...

# %%
#doc2_vec_model = Doc2Vec(documents, vector_size=DIMENSIONS, window=WINDOW, min_count=5, seed=0)

# %%
#len(doc2_vec_model.dv)

# %%
#doc2_vec_model.dv[0]

# %%
#all_d2v_vecs = [doc2_vec_model.dv[i] for i in range(len(doc2_vec_model.dv))]
#print(len(all_d2v_vecs))

# %%
#df["d2v"] = all_d2v_vecs

# %%
#df.head()

# %%
print(df['embedding_64'][0].shape)
# Out:
# (64,)

# %% [markdown]
# ### Get the explained variance

# %%
from sklearn.decomposition import PCA

# %%
# PCA analysis
variance_explained = []
for dim in dims:
    col = 'embedding_'+str(dim)
    print(col)
    embeddings=df[col].tolist()
    pca = PCA(n_components=2)
    pca.fit(embeddings)
    variance_explained.append(pca.explained_variance_ratio_.sum().round(2))
# Out:
# embedding_16
# embedding_32
# embedding_64
# embedding_128
# embedding_256
# embedding_512

# %%
print(variance_explained)
# Out:
# [0.37, 0.4, 0.42, 0.44, 0.45, 0.46]

# %%
# Plot variance explained
import matplotlib.pyplot as plt
plt.plot(dims, variance_explained)
# Set x ticks
plt.xticks(dims,rotation=90)

plt.title('Variance Explained vs Dimensionality')
plt.xlabel('Dimensions')
plt.ylabel('Variance Explained')
plt.savefig("/gdrive/MyDrive/Projects/CodeErrorsNLP/embeddings_variance.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# Best Doc2Vec dimension seems to be 128

# %% [markdown]
# ## Let's find the best k for clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score

# %%
# Range of k to check
k_range = range(2, 20)

sil_scores = []
cal_scores = []

for k in k_range:
  # Cluster data into k clusters
  kmeans = KMeans(n_clusters=k)
  clusters = kmeans.fit_predict(df['embedding_128'].tolist())

  # Score with metrics
  sil_score = silhouette_score(df['embedding_128'].tolist(), clusters)
  sil_scores.append(sil_score)

  cal_score = calinski_harabasz_score(df['embedding_128'].tolist(), clusters)
  cal_scores.append(cal_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Plot scores
plt.plot(k_range, sil_scores, label='Silhouette')
new_list = range(math.floor(min(k_range)), math.ceil(max(k_range))+1)
plt.xticks(new_list)
plt.title('Silhouette Cluster Evaluation Scores')
plt.xlabel('Size of k')
plt.ylabel('Score')
#plt.legend()
plt.savefig("/gdrive/MyDrive/Projects/CodeErrorsNLP/shilouette_k.pdf", bbox_inches='tight')
plt.show()

# %%
print(sil_scores)
# Out:
# [0.16914222, 0.17126867, 0.1975977, 0.22151886, 0.23418295, 0.24773848, 0.24341401, 0.20766471, 0.21378537, 0.18542795, 0.17552306, 0.16465484, 0.16397478, 0.15368085, 0.13538295, 0.13746385, 0.12685715, 0.11847482]

# %%
# Plot scores
plt.plot(k_range, cal_scores, label='Calinski-Harabasz')
new_list = range(math.floor(min(k_range)), math.ceil(max(k_range))+1)
plt.xticks(new_list)
plt.title('Cluster Evaluation Scores')
plt.xlabel('k')
plt.legend()
plt.show()

# %% [markdown]
# It looks that k=7 is fine

# %% [markdown]
# ### Lets use the 128 dimensions and 7 clusters

# %%
all_d2v_vecs = df['embedding_128'].tolist()

# %%
np.shape(all_d2v_vecs)
# Out:
# (13993, 128)

# %%
all_d2v_vecs[0]
# Out:
# array([ 0.04212342, -0.0325226 ,  0.0192305 ,  0.01110134,  0.01904168,
#         0.00454772, -0.05129881, -0.03209109, -0.00644553, -0.00497828,
#         0.0316824 ,  0.05322967, -0.04975457, -0.02358725,  0.02376013,
#        -0.00262535,  0.00852317,  0.01554863,  0.00756856, -0.01586711,
#         0.01239421,  0.04039476,  0.04426681, -0.05272445, -0.04504972,
#         0.00168574, -0.01408917,  0.03144519,  0.02401227, -0.02872684,
#         0.01341094, -0.06975647, -0.0147953 ,  0.04774754, -0.03764909,
#         0.02464539, -0.00139881, -0.06052272,  0.03691787,  0.0104303 ,
#         0.04723091, -0.04117157, -0.04266255, -0.00953685,  0.00618768,
#        -0.02906322,  0.0845167 ,  0.01178139, -0.01776677,  0.00607533,
#         0.00516171, -0.06105427,  0.00382651,  0.07011714, -0.04924889,
#        -0.01691028, -0.03978679,  0.02046869,  0.06536144,  0.0356103 ,
#         0.00256154, -0.03760792,  0.00534136,  0.04030311, -0.00920921,
#         0.04651385,  0.04419082, -0.00410043,  0.05101675, -0.00913209,
#        -0.10957777,  0.00563978,  0.0493261 , -0.0490384 , -0.01948669,
#         0.00851629, -0.01116608,  0.00149914, -0.04898943, -0.06030592,
#         0.03980298,  0.00653673, -0.04429072,  0.03122446, -0.03270391,
#        -0.02512161, -0.0157184 , -0.03998648, -0.00117012, -0.03336968,
#         0.02646034,  0.08158922,  0.04617609, -0.05853351, -0.02161846,
#         0.03337312,  0.03668924,  0.0018411 ,  0.00942213, -0.02267783,
#         0.0278237 ,  0.03306758,  0.0071806 ,  0.00666344,  0.10237409,
#        -0.00656305,  0.00355689, -0.06078061, -0.02721707,  0.07344646,
#        -0.00840254, -0.02355126,  0.04858758,  0.02889906,  0.02475818,
#         0.00174856, -0.01652316,  0.00229535,  0.02275248, -0.00306053,
#         0.01218254, -0.05783079, -0.02770323, -0.00588195,  0.01059654,
#        -0.00969293, -0.01084266,  0.06175298], dtype=float32)

# %%
kmeans = KMeans(n_clusters=7, random_state=0).fit(all_d2v_vecs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.labels_
# Out:
# array([6, 5, 6, ..., 4, 4, 4], dtype=int32)

# %%
df["d2v_clusters"] = kmeans.labels_
df
# Out:
#                                                    Error  \
# 0                         Missing package-info java file
# 1      Utility classes should not have a public or de...
# 2                              Missing a Javadoc comment
# 3                         Parameter args should be final
# 4      File contains tab characters (this is the firs...
# ...                                                  ...
# 13988                     Parameter args should be final
# 13989                           Line has trailing spaces
# 13990                           Line has trailing spaces
# 13991                           Line has trailing spaces
# 13992                           Line has trailing spaces
#
#                            Category  \
# 0                   JavadocPackage
# 1      HideUtilityClassConstructor
# 2             MissingJavadocMethod
# 3                  FinalParameters
# 4                 FileTabCharacter
# ...                             ...
# 13988              FinalParameters
# 13989             RegexpSingleline
# 13990             RegexpSingleline
# 13991             RegexpSingleline
# 13992             RegexpSingleline
#
#                                                    clean  \
# 0                         missing package-info java file
# 1      utility classes should not have a public or de...
# 2                              missing a javadoc comment
# 3           parameter <a_parameter_name> should be final
# 4      file contains tab characters (this is the firs...
# ...                                                  ...
# 13988       parameter <a_parameter_name> should be final
# 13989                           line has trailing spaces
# 13990                           line has trailing spaces
# 13991                           line has trailing spaces
# 13992                           line has trailing spaces
#
#                                                 textList  \
# 0                    [missing, package-info, java, file]
# 1      [utility, classes, should, not, have, a, publi...
# 2                         [missing, a, javadoc, comment]
# 3      [parameter, <a_parameter_name>, should, be, fi...
# 4      [file, contains, tab, characters, (this, is, t...
# ...                                                  ...
# 13988  [parameter, <a_parameter_name>, should, be, fi...
# 13989                      [line, has, trailing, spaces]
# 13990                      [line, has, trailing, spaces]
# 13991                      [line, has, trailing, spaces]
# 13992                      [line, has, trailing, spaces]
#
#                                             embedding_16  \
# 0      [-0.015551005, 0.033605706, 0.024641672, -0.06...
# 1      [-0.1368318, 0.038364783, -0.036842555, -0.083...
# 2      [0.031338092, 0.14706026, -0.11331174, 0.04538...
# 3      [0.055871285, -0.046852883, -0.018312456, -0.1...
# 4      [0.06927245, 0.03268087, -0.068136595, 0.05919...
# ...                                                  ...
# 13988  [-0.017437598, -0.028360685, -0.027452977, -0....
# 13989  [0.03976631, -0.047795795, -0.14890482, -0.023...
# 13990  [0.021147855, -0.048736546, -0.13077089, -0.13...
# 13991  [0.106154434, -0.04105901, -0.14734316, -0.172...
# 13992  [0.08438272, -0.008470421, -0.16158903, -0.108...
#
#                                             embedding_32  \
# 0      [0.11356431, 0.12167054, 0.046877578, 0.002169...
# 1      [0.05528406, 0.085993946, 0.02528275, 0.040453...
# 2      [0.18168919, 0.13130507, 0.037680723, 0.062324...
# 3      [0.1184343, 0.10719438, 0.04544073, 0.07976507...
# 4      [-0.006012668, 0.08069822, -0.06056278, 0.0127...
# ...                                                  ...
# 13988  [0.033433095, 0.1035474, 0.066268526, 0.049413...
# 13989  [0.0939853, 0.09544211, 0.042006735, 0.1033304...
# 13990  [-0.023283452, 0.093352504, 0.09954168, 0.0819...
# 13991  [0.009344032, 0.16401994, 0.10174729, 0.096476...
# 13992  [-0.004356122, 0.18630749, 0.09492036, 0.10731...
#
#                                             embedding_64  \
# 0      [0.048794147, -0.009825103, 0.04454054, -0.049...
# 1      [-0.0146215875, -0.06162069, 0.0002887169, 0.0...
# 2      [0.070900455, -0.011056697, 0.04327284, -0.039...
# 3      [0.027767941, 0.013156969, 0.0653381, -0.07377...
# 4      [-0.012465264, -0.02325621, -0.030042764, 0.03...
# ...                                                  ...
# 13988  [0.020715825, -0.012997081, 0.05269249, -0.067...
# 13989  [0.07325272, -0.03849617, 0.055569243, -0.0103...
# 13990  [0.07701433, -0.07344203, 0.016142486, -0.0310...
# 13991  [0.08924181, -0.055800926, 0.059920028, -0.030...
# 13992  [0.059774525, -0.046659097, 0.0238455, -0.0343...
#
#                                            embedding_128  \
# 0      [0.042123422, -0.0325226, 0.0192305, 0.0111013...
# 1      [0.016139103, -0.013041689, 0.028586313, -0.01...
# 2      [0.018523373, -0.008445454, 0.0015263191, 0.02...
# 3      [0.05428207, -0.044264376, -0.0142417755, 0.03...
# 4      [0.038426444, -0.031036995, 0.007968803, 0.011...
# ...                                                  ...
# 13988  [0.03108481, -0.021686932, -0.02828657, 0.0236...
# 13989  [0.03709314, -0.052055776, 0.012227272, -0.047...
# 13990  [0.01531626, -0.048278086, 0.00044611513, -0.0...
# 13991  [0.028992455, -0.04777034, 0.00036397, -0.0401...
# 13992  [0.03332404, -0.046311926, -0.00634792, -0.037...
#
#                                            embedding_256  \
# 0      [0.015540451, -0.0077465456, -0.024257822, -0....
# 1      [-0.0023854873, -0.017778205, -0.017936917, 0....
# 2      [0.041183252, -0.0039972975, -0.031711332, -0....
# 3      [-0.0069575994, -0.0017535925, -0.023125423, 0...
# 4      [0.019988338, 0.015296029, 0.019334216, -0.018...
# ...                                                  ...
# 13988  [0.0030510053, 0.008608238, -0.02912862, -0.00...
# 13989  [0.022719927, -0.01298718, -0.04768765, 0.0168...
# 13990  [0.008895125, -0.026604237, -0.052089285, 0.03...
# 13991  [0.019257855, -0.013666513, -0.05962945, 0.033...
# 13992  [0.020011328, -0.013535501, -0.051261876, 0.01...
#
#                                            embedding_512  d2v_clusters
# 0      [0.0032496152, 0.01017696, -0.005061691, 0.001...             6
# 1      [0.00023381141, -0.0034163457, -0.008104014, 0...             5
# 2      [0.0015146778, 0.008322123, -0.017599704, -0.0...             6
# 3      [0.014764239, 0.0073536434, -0.007747488, 0.00...             0
# 4      [0.025814686, 0.01866307, -0.017561177, -0.000...             0
# ...                                                  ...           ...
# 13988  [-0.0020777995, 0.016683197, 0.008828386, 0.03...             0
# 13989  [-0.0005067968, 0.0057832906, -0.013292474, -0...             4
# 13990  [0.0034122318, -0.0012746786, -0.021293981, -0...             4
# 13991  [-0.0051173614, 0.004493387, -0.0075209527, -0...             4
# 13992  [-0.0057715364, -0.006163076, -0.011958807, -0...             4
#
# [13993 rows x 11 columns]

# %%
ax = df['d2v_clusters'].value_counts().plot.bar()

ax.set_title('Distribution of Clusters')
ax.set_xlabel('Clusters')
ax.set_ylabel('Number of Errors')

plt.show()

# %%
# Remove whitespace around plot
fig = ax.get_figure()
# fig.tight_layout()

# Save just the plot area to PDF
fig.savefig('/gdrive/MyDrive/Projects/CodeErrorsNLP/hist_clusters.pdf', bbox_inches='tight')

# %%
clust_number = 2
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 7          line is longer than characters (found )
# 9          line is longer than characters (found )
# 18         line is longer than characters (found )
# 26       <operator> should be on the previous line
# 27         line is longer than characters (found )
#                            ...
# 13909      line is longer than characters (found )
# 13946      line is longer than characters (found )
# 13952      line is longer than characters (found )
# 13954      line is longer than characters (found )
# 13964      line is longer than characters (found )
# Name: clean, Length: 1495, dtype: object
# 1495

# %%
clust_number = 0
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 3             parameter <a_parameter_name> should be final
# 4        file contains tab characters (this is the firs...
# 13            parameter <a_parameter_name> should be final
# 22                                line has trailing spaces
# 25            parameter <a_parameter_name> should be final
#                                ...
# 13979            <operator> should be on the previous line
# 13980            <operator> should be on the previous line
# 13982            <operator> should be on the previous line
# 13986            <operator> should be on the previous line
# 13988         parameter <a_parameter_name> should be final
# Name: clean, Length: 2329, dtype: object
# 2329

# %%
clust_number = 5
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 1        utility classes should not have a public or de...
# 11       utility classes should not have a public or de...
# 19                          missing package-info java file
# 20       utility classes should not have a public or de...
# 34       utility classes should not have a public or de...
#                                ...
# 13947              <operator> construct must use <bracket>
# 13960                     file does not end with a newline
# 13962      javadoc comment is placed in the wrong location
# 13965    utility classes should not have a public or de...
# 13966     name <a_name> must match pattern '^a-za-za-z-*$'
# Name: clean, Length: 1799, dtype: object
# 1799

# %%
clust_number = 1
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 21       <operator> is not preceded with whitespace
# 28          line is longer than characters (found )
# 31         <operator> is not followed by whitespace
# 32       <operator> is not preceded with whitespace
# 45       <operator> is not preceded with whitespace
#                             ...
# 13958      <operator> is not followed by whitespace
# 13973      <operator> is not followed by whitespace
# 13974      <operator> is not followed by whitespace
# 13976    <operator> is not preceded with whitespace
# 13981     <operator> should be on the previous line
# Name: clean, Length: 4397, dtype: object
# 4397

# %%
clust_number = 6
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 0                           missing package-info java file
# 2                                missing a javadoc comment
# 10                          missing package-info java file
# 12                               missing a javadoc comment
# 14                                    '' is a magic number
#                                ...
# 13977                                  avoid nested blocks
# 13983                     file does not end with a newline
# 13984                       missing package-info java file
# 13985    utility classes should not have a public or de...
# 13987                            missing a javadoc comment
# Name: clean, Length: 1853, dtype: object
# 1853

# %%
clust_number = 3
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 175                                   '' is a magic number
# 287        javadoc comment is placed in the wrong location
# 331                        'int' is followed by whitespace
# 384                        'int' is followed by whitespace
# 402                        'int' is followed by whitespace
#                                ...
# 13916    <operator> should be on the same line as the n...
# 13924    <operator> should be on the same line as the n...
# 13942                      ';' is preceded with whitespace
# 13970                 <braket> is preceded with whitespace
# 13975                 <braket> is preceded with whitespace
# Name: clean, Length: 578, dtype: object
# 578

# %%
clust_number = 4
print(df[df['d2v_clusters'] == clust_number]['clean'])
print(df[df['d2v_clusters'] == clust_number]['clean'].count())
# Out:
# 5        line has trailing spaces
# 6        line has trailing spaces
# 8        line has trailing spaces
# 23       line has trailing spaces
# 30       line has trailing spaces
#                    ...
# 13968    line has trailing spaces
# 13989    line has trailing spaces
# 13990    line has trailing spaces
# 13991    line has trailing spaces
# 13992    line has trailing spaces
# Name: clean, Length: 1542, dtype: object
# 1542

# %% [markdown]
# ### Silhouette Score

# %%
from yellowbrick.cluster import SilhouetteVisualizer


# Assuming 'embedding128' is your pandas Series containing embeddings
# Convert the Series to a list of lists
embedding_list = df['embedding_128'].tolist()
embedding_list_of_lists = np.array([embedding.tolist() for embedding in embedding_list])

# Create a SilhouetteVisualizer instance
title = "Silhouette Plot of k-means Clustering"
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick', title=title)


# Fit the visualizer with the standardized embedding data
visualizer.fit(embedding_list_of_lists)
# Export the plot to a PDF with a tight layout
visualizer.show(outpath="/gdrive/MyDrive/Projects/CodeErrorsNLP/silhouette_plot.pdf")

# Display the visualization
visualizer.poof()
# Out:
# <Axes: title={'center': 'Silhouette Plot of k-means Clustering'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# ### Let's use UMAP to plot the clusters

# %%
data_embeds = pd.DataFrame()
data_embeds['embeds'] = df["embedding_128"]
print(data_embeds.head())
print(data_embeds.shape)
# Out:
#                                               embeds
# 0  [0.042123422, -0.0325226, 0.0192305, 0.0111013...
# 1  [0.016139103, -0.013041689, 0.028586313, -0.01...
# 2  [0.018523373, -0.008445454, 0.0015263191, 0.02...
# 3  [0.05428207, -0.044264376, -0.0142417755, 0.03...
# 4  [0.038426444, -0.031036995, 0.007968803, 0.011...
# (13993, 1)

# %%
# !pip install --quiet umap-learn
# Out:
# ERROR: Operation cancelled by user

# %%
import umap # REDUCE DIMENSIONALITY
import seaborn as sns
sns.color_palette('colorblind')
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
X_umap = umap.UMAP().fit_transform(data_embeds['embeds'].tolist())

# %%
X_umap
# Out:
# array([[ 9.383938  ,  9.121459  ],
#        [11.193618  ,  6.2259903 ],
#        [13.633108  , 13.575803  ],
#        ...,
#        [-1.3828281 ,  2.6887016 ],
#        [-0.59950525,  3.225573  ],
#        [-1.2167898 ,  2.557843  ]], dtype=float32)

# %%
data_df = pd.DataFrame()
data_df['x'] = X_umap[:,0]
data_df['y'] = X_umap[:, 1]
data_df['cluster'] = df['d2v_clusters']

# %%
data_df
# Out:
#                x          y  cluster
# 0       9.383938   9.121459        6
# 1      11.193618   6.225990        5
# 2      13.633108  13.575803        6
# 3       6.248359  14.988681        0
# 4       9.637664   8.771388        0
# ...          ...        ...      ...
# 13988   5.956225  14.159636        0
# 13989  -1.108768   3.284763        4
# 13990  -1.382828   2.688702        4
# 13991  -0.599505   3.225573        4
# 13992  -1.216790   2.557843        4
#
# [13993 rows x 3 columns]

# %%
data_df['clus'] = data_df['cluster'].apply(lambda x: str(x))
data_df
# Out:
#                x          y  cluster clus
# 0       9.383938   9.121459        6    6
# 1      11.193618   6.225990        5    5
# 2      13.633108  13.575803        6    6
# 3       6.248359  14.988681        0    0
# 4       9.637664   8.771388        0    0
# ...          ...        ...      ...  ...
# 13988   5.956225  14.159636        0    0
# 13989  -1.108768   3.284763        4    4
# 13990  -1.382828   2.688702        4    4
# 13991  -0.599505   3.225573        4    4
# 13992  -1.216790   2.557843        4    4
#
# [13993 rows x 4 columns]

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=data_df, x="x", y="y", hue='clus')
plt.show()

# %% [markdown]
# What about PCA and Doc2Vec?

# %%
#Getting unique labels
pca = PCA(2)
#Transform the data
X_pca = pca.fit_transform(data_embeds['embeds'].tolist())
X_pca
# Out:
# array([[ 0.10471931, -0.04918581],
#        [-0.02453561,  0.15038174],
#        [ 0.02381294,  0.13626997],
#        ...,
#        [ 0.22103497, -0.04447044],
#        [ 0.15803311, -0.05357   ],
#        [ 0.2183145 , -0.04110624]])

# %%
data_df = pd.DataFrame()
data_df['x'] = X_pca[:,0]
data_df['y'] = X_pca[:, 1]
data_df['cluster'] = df['d2v_clusters']

# %%
data_df
# Out:
#               x         y  cluster
# 0      0.104719 -0.049186        6
# 1     -0.024536  0.150382        5
# 2      0.023813  0.136270        6
# 3      0.215116 -0.027961        0
# 4      0.039066  0.030010        0
# ...         ...       ...      ...
# 13988  0.179753  0.080133        0
# 13989  0.152248 -0.045696        4
# 13990  0.221035 -0.044470        4
# 13991  0.158033 -0.053570        4
# 13992  0.218314 -0.041106        4
#
# [13993 rows x 3 columns]

# %%
data_df['clus'] = data_df['cluster'].apply(lambda x: str(x))
data_df
# Out:
#               x         y  cluster clus
# 0      0.104719 -0.049186        6    6
# 1     -0.024536  0.150382        5    5
# 2      0.023813  0.136270        6    6
# 3      0.215116 -0.027961        0    0
# 4      0.039066  0.030010        0    0
# ...         ...       ...      ...  ...
# 13988  0.179753  0.080133        0    0
# 13989  0.152248 -0.045696        4    4
# 13990  0.221035 -0.044470        4    4
# 13991  0.158033 -0.053570        4    4
# 13992  0.218314 -0.041106        4    4
#
# [13993 rows x 4 columns]

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=data_df, x="x", y="y", hue='clus')

plt.title("Clusters of errors")
plt.savefig("/gdrive/MyDrive/Projects/CodeErrorsNLP/cluster_errors.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### t-SNE

# %% [markdown]
# ## Let's get error closest to the centroid in each cluster

# %%
centroids = kmeans.cluster_centers_

# %%
len(centroids)
# Out:
# 7

# %%
from sklearn.neighbors import NearestNeighbors

# %%
# Find closest to each centroid
closest_docs = []
for c, centroid in enumerate(centroids):
    nbrs = NearestNeighbors(n_neighbors=1).fit(df[df['d2v_clusters']==c]['embedding_128'].tolist())
    distances, indices = nbrs.kneighbors(centroid.reshape(1,-1))
    closest_doc = df[df['d2v_clusters']==c]['clean'].iloc[indices[0,0]]
    closest_doc_cat = df[df['d2v_clusters']==c]['Category'].iloc[indices[0,0]]
    closest_docs.append({c:[closest_doc, closest_doc_cat]})

# %%
closest_docs
# Out:
# [{0: ['parameter <a_parameter_name> should be final', 'FinalParameters ']},
#  {1: ['<operator> is not preceded with whitespace', 'WhitespaceAround ']},
#  {2: ['line is longer than characters (found )', 'LineLength ']},
#  {3: ['<braket> is followed by whitespace', 'ParenPad ']},
#  {4: ['line has trailing spaces', 'RegexpSingleline ']},
#  {5: ["name <a_name> must match pattern '^a-za-za-z-*$'", 'TypeName ']},
#  {6: ['missing a javadoc comment', 'MissingJavadocMethod ']}]

# %% [markdown]
# ### Checking the XML file
#
# * {0: ['parameter <a_parameter_name> should be final', 'FinalParameters ']}, Miscellaneous other checks.
# * {1: ['<operator> is not preceded with whitespace', 'WhitespaceAround ']}, Checks for whitespace.
# * {2: ['line is longer than characters (found )', 'LineLength ']},Checks for Size Violations
# * {3: ['<braket> is followed by whitespace', 'ParenPad ']},Checks for whitespace
# * {4: ['line has trailing spaces', 'RegexpSingleline ']},Miscellaneous other checks.
# *  {5: ["name <a_name> must match pattern '^a-za-za-z-*$'", 'TypeName ']},Checks for Naming Conventions.
# * {6: ['missing a javadoc comment', 'MissingJavadocMethod ']},Checks for Javadoc comments

# %% [markdown]
# ## Let's try summarizing the whole cluster

# %%
# !pip3 install gensim==3.6.0 # summarization was deprecated from 4.0
# Out:
# Collecting gensim==3.6.0
#   Downloading gensim-3.6.0.tar.gz (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.10/dist-packages (from gensim==3.6.0) (1.23.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from gensim==3.6.0) (1.11.2)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from gensim==3.6.0) (1.16.0)
# Requirement already satisfied: smart_open>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from gensim==3.6.0) (6.4.0)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.6.0-cp310-cp310-linux_x86_64.whl size=23778007 sha256=098bbee552dd2794d87873ee0782daf9760894e3af51c805ff04646262a63198
#   Stored in directory: /root/.cache/pip/wheels/00/e8/47/96f55c3144a5ea3537f549f7a97607011f5004b9f13fa8dcc5
# Successfully built gensim
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.2
#     Uninstalling gensim-4.3.2:
#       Successfully uninstalled gensim-4.3.2
# Successfully installed gensim-3.6.0

# %%
from gensim.summarization import summarize

# %%
# Group docs by cluster
docs_by_cluster = df.groupby('d2v_clusters')['Error']

# %%
texts = []
for d in docs_by_cluster:
    #print(d[1].values)
    text = ".".join(txt for txt in d[1].values)
    texts.append(text)

# %%
len(texts)
# Out:
# 7

# %%
# Generate summary for each cluster (didn't work well)
#cluster_summaries = {}
#for cluster_id, cluster_docs in enumerate(texts):
#    #all_text = " ".join(cluster_docs.values)
#    #print(cluster_docs)
#    summary = summarize(cluster_docs, word_count=10)
#    cluster_summaries[cluster_id] = summary

# %%
texts[0]
# Out:
# "Parameter args should be final.File contains tab characters (this is the first instance).Parameter args should be final.Line has trailing spaces.Parameter args should be final.Parameter args should be final.Parameter args should be final.Parameter args should be final.Parameter args should be final.'||' is not preceded with whitespace.'{' at column should be on the previous line.File contains tab characters (this is the first instance).Parameter args should be final.Utility classes should not have a public or default constructor.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter values should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter list should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter list should be final.'{' at column should be on the previous line.Parameter list should be final.'{' at column should be on the previous line.Parameter list should be final.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'+' is not followed by whitespace.Parameter x should be final.Parameter y should be final.Parameter z should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter x should be final.Parameter y should be final.Parameter z should be final.'{' at column should be on the previous line.Parameter x should be final.Parameter y should be final.Parameter z should be final.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.Parameter x should be final.Parameter y should be final.Parameter z should be final.Parameter x should be final.Parameter y should be final.Parameter z should be final.Parameter x should be final.Parameter y should be final.Parameter z should be final.Parameter args should be final.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter vw should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.Parameter args should be final.Parameter fileName should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter fileName should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.Using the ' *' form of import should be avoided - java.io.*.Utility classes should not have a public or default constructor.Parameter args should be final.'{' at column should be on the previous line.'{' at column should be on the previous line.'{' at column should be on the previous line.First sentence should end with a period.Parameter x should be final.Parameter y should  ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[0])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(texts[0])

print(frequencies)
# Out:
# {'Parameter': 1041, 'final': 1041, 'File': 40, 'contains': 16, 'tab': 7, 'characters': 20, 'First': 40, 'instance': 7, 'line': 1126, 'trailing': 9, 'spaces': 9, 'preceded': 12, 'whitespace': 20, 'column': 1074, 'previous': 1072, 'Utility': 16, 'classes': 16, 'public': 16, 'default': 16, 'constructor': 16, 'values': 8, 'list': 17, 'followed': 8, 'x': 104, 'y': 106, 'z': 103, 'vw': 1, 'fileName': 7, 'Using': 20, 'form': 20, 'import': 21, 'avoided': 20, 'java': 36, 'io': 6, 'sentence': 31, 'end': 46, 'period': 31, 'Redundant': 1, 'lang': 2, 'package': 18, 'Math': 1, 'b': 16, 'input': 7, 'intArray': 4, 'variable': 14, "input'": 1, 'must': 14, 'private': 5, 'accessor': 5, 'arg': 375, 'Javadoc': 7, 'comment': 7, 'placed': 6, 'wrong': 6, 'location': 6, 'array': 30, 'firstArray': 2, 'secondArray': 2, 'n': 9, 'next': 9, 'part': 9, 'multi': 9, 'block': 18, 'statement': 19, 'one': 9, 'directly': 9, 'multiple': 9, 'try': 9, 'catch': 9, 'finally': 9, 'length': 4, 'Conditional': 2, 'logic': 2, 'removed': 2, 'Expression': 2, 'simplified': 2, 'longer': 13, 'found': 13, 'str': 47, 'newline': 15, 'inputFileName': 1, 'outputFileName': 1, 'Missing': 18, 'info': 17, 'javax': 3, 'swing': 3, 'myString': 4, 'break': 3, 'magic': 11, 'number': 13, 'new': 13, 'got': 9, 'want': 9, 'method': 8, 'second': 2, 'num': 3, 'small': 1, 'big': 1, 'util': 10, 'declaration': 9, 'arr': 17, 'parsed': 4, 'counter': 5, "if'": 2, 'temperature': 1, 'j': 1, 'pathName': 4, 'alone': 3, 'year': 1, 'interest': 1, 'balance': 1, 'inputString': 3, 'inputFile': 2, 'outputFile': 2, 'return': 1, 'tag': 2, 'present': 1, 'description': 1, "SUCCESS'": 1, 'sequence': 1, 'score': 2, 'startInclusive': 1, 'endInclusive': 1, 'grade': 2, "PASS_STATUS'": 1, "FAIL_STATUS'": 1, 'word': 2, 'filePath': 2, 'mainArray': 4, 'randomNumbers': 8, 'argv': 1, 'intsInList': 4, 'modulusValue': 1, 'time': 5, 'mil': 1, "timeDifference'": 1, 'output': 2, 'lineNumber': 1, 'newFileName': 1, 'newName': 1, 'c': 3, 'firstNumber': 3, 'secondNumber': 3, 'thirdNumber': 3, 'result': 3, "for'": 2, 'stream': 1, 'inputList': 1, 'min': 1, 'max': 1, 'fnForOdd': 1, 'fnForEven': 1, 'obj': 1, 'g': 1, 'FirstNum': 2, 'SecNum': 3, 'ThirdNum': 3, 'charArray': 1, 'userInput': 1, 'amount': 1, 'userStringInput': 1, 'text': 1, 'Unknown': 1, "Assignemnt'": 1, 't': 2, 'Empty': 1, 'data': 4}

# %%
texts[1]
# Out:
# "'{' is not preceded with whitespace.Line is longer than characters (found ).'}' is not followed by whitespace.'}' is not preceded with whitespace.'{' is not preceded with whitespace.'{' is not preceded with whitespace.'{' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'=' is not followed by whitespace.'=' is not preceded with whitespace.'*' is not followed by whitespace.'*' is not preceded with whitespace.'if' is not followed by whitespace.'if' is not followed by whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'||' is not followed by whitespace.'||' is not preceded with whitespace.'==' is not followed by whitespace.'==' is not preceded with whitespace.'+' is not followed by whitespace.'+' is not followed by whitespace.'+' is not preceded with whitespace.'+' is not followed by whitespace.'+' is not preceded with whitespace.'+' is not followed by whitespace.'+' is not preceded with whitespace.'+' is not followed by whitespace.'+' is not preceded with whitespace.'+' is not followed by whitespace.'+' is not preceded with whitespace.'+' is not followed by white ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[1])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(texts[1])

print(frequencies)
# Out:
# {'preceded': 1636, 'whitespace': 4227, 'line': 89, 'longer': 15, 'characters': 19, 'found': 15, 'followed': 2591, "if'": 705, 'File': 21, 'end': 14, 'newline': 12, 'column': 73, 'next': 24, 'part': 24, 'multi': 24, 'block': 48, 'statement': 27, 'one': 24, 'directly': 24, 'contains': 28, 'multiple': 24, 'try': 24, 'catch': 24, 'finally': 24, "else'": 151, "for'": 310, "list'": 1, 'Utility': 13, 'classes': 13, 'public': 13, 'default': 13, 'constructor': 13, 'return': 1, 'tag': 1, 'present': 1, 'description': 1, "while'": 84, 'previous': 44, 'Conditional': 2, 'logic': 2, 'removed': 2, 'Javadoc': 18, 'comment': 18, 'placed': 18, 'wrong': 18, 'location': 18, 'Expression': 4, 'simplified': 4, 'Missing': 5, 'package': 5, 'info': 5, 'java': 5, 'break': 5, 'new': 1, 'magic': 9, 'number': 9, 'Name': 1, "METHOD_STACK_INDEX'": 1, 'must': 6, 'match': 1, 'pattern': 1, 'za': 2, 'Z': 1, 'construct': 2, 'use': 2, 's': 2, "typecast'": 22, 'tab': 4, 'first': 6, 'instance': 4, "return'": 5, "finally'": 2, "catch'": 18, "try'": 8, 'sentence': 2, 'period': 2, 'variable': 3, 'declaration': 3, "double'": 1, 'Unused': 3, 'import': 4, 'javax': 3, 'lang': 2, 'model': 2, 'element': 1, 'VariableElement': 1, 'org': 1, 'wc': 1, 'dom': 1, 'Range': 2, 'Array': 1, 'brackets': 1, 'illegal': 1, 'position': 1, 'Using': 1, 'form': 1, 'avoided': 1, 'swing': 1, "switch'": 4, 'util': 1, 'ElementScanner': 1}

# %%
texts[2]
# Out:
# "Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).'{' at column should be on the previous line.Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).'*' is not preceded with whitespace.Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Conditional logic can be removed.Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).'{' at column should be on the previous line.Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).'{' at column should be on the previous line.Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (found ).Line is longer than characters (fou ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[2])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(texts[2])

print(frequencies)
# Out:
# {'Line': 1424, 'longer': 1377, 'characters': 1382, 'found': 1377, 'column': 37, 'previous': 29, 'preceded': 2, 'whitespace': 9, 'Conditional': 5, 'logic': 5, 'removed': 5, 'Expression': 3, 'simplified': 3, 'trailing': 10, 'spaces': 10, 'followed': 7, 'Utility': 20, 'classes': 20, 'public': 20, 'default': 20, 'constructor': 20, 'next': 7, 'part': 7, 'multi': 7, 'block': 14, 'statement': 7, 'one': 7, 'directly': 7, 'contains': 12, 'multiple': 7, 'try': 7, 'catch': 7, 'finally': 7, 'magic': 7, 'number': 7, 'File': 11, 'tab': 5, 'First': 15, 'instance': 5, 'Missing': 2, 'package': 2, 'info': 2, 'java': 2, 'Array': 5, 'brackets': 5, 'illegal': 5, 'position': 5, 'sentence': 10, 'end': 14, 'period': 10, "if'": 3, 'construct': 1, 'must': 1, 'use': 1, 's': 1, 'break': 1, 'newline': 4}

# %%
texts[3]
# Out:
# "'' is a magic number.Javadoc comment is placed in the wrong location.'int' is followed by whitespace.'int' is followed by whitespace.'int' is followed by whitespace.'int' is followed by whitespace.'int' is followed by whitespace.'(' is preceded with whitespace.')' is preceded with whitespace.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).')' is preceded with whitespace.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).')' is preceded with whitespace.'(' is preceded with whitespace.')' is preceded with whitespace.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'(' is followed by whitespace.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).File contains tab characters (this is the first instance).File contains tab characters (this is the first instance).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).Parameter z should be final.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).')' is preceded with whitespace.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'(' is preceded with whitespace.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).File contains tab characters (this is the first instance).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).Javadoc comment is placed in the wrong location.'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a multi-block statement (one that directly contains multiple blocks if/else-if/else do/while or try/catch/finally).'}' at column should be on the same line as the next part of a mul ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[3])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(texts[3])

print(frequencies)
# Out:
# {'magic': 4, 'number': 4, 'javadoc': 24, 'comment': 3, 'placed': 2, 'wrong': 2, 'location': 2, "int'": 24, 'followed': 111, 'whitespace': 246, 'preceded': 135, 'column': 252, 'line': 259, 'next': 241, 'part': 241, 'multi': 241, 'block': 485, 'statement': 248, 'one': 242, 'directly': 241, 'contains': 248, 'multiple': 241, 'try': 241, 'catch': 241, 'finally': 241, 'File': 11, 'tab': 7, 'characters': 7, 'first': 10, 'instance': 7, 'Parameter': 5, 'z': 1, 'final': 5, 'variable': 7, 'definition': 1, 'per': 1, 'allowed': 1, 'previous': 4, 'end': 7, 'newline': 4, 'trailing': 4, 'spaces': 4, 'break': 7, 'new': 2, 'Class': 21, "NumberProperties'": 1, 'looks': 21, 'designed': 21, 'extension': 21, 'subclassed': 21, 'method': 25, "runUnitTest'": 4, 'explains': 21, 'safely': 21, 'Inner': 2, 'assignments': 2, 'avoided': 6, 'declaration': 4, 'must': 6, 'Empty': 3, "LabFive'": 8, "allTheSame'": 3, "average'": 2, "theSmallest'": 2, "sorted'": 3, 'Utility': 3, 'classes': 3, 'public': 3, 'default': 3, 'constructor': 3, 'Using': 4, 'form': 4, 'import': 6, 'java': 8, 'util': 3, "StreamOrder'": 2, "getInput'": 1, 'Duplicate': 3, 'return': 3, 'tag': 3, "StringProperties'": 1, "runTest'": 1, "Grade'": 1, "grades'": 1, 'private': 2, 'accessor': 2, "String'": 3, "Methods'": 3, "allDifferent'": 1, 'sentence': 3, 'period': 3, 'Redundant': 2, 'lang': 4, 'package': 2, 'Math': 2, "input'": 1, 'args': 1, 'arr': 1, 'Avoid': 3, 'nested': 3, 'Missing': 1, "Numbers'": 1, 'io': 1, "Elements'": 4, "getFirstAndLast'": 1, "getEvenElementsIndex'": 1, "getEvenElementsValues'": 1, "getReverseElements'": 1}

# %%
texts[4]
# Out:
# "Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.'{' at column should be on the previous line.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line has trailing spaces.Line ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[4])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(texts[4])

print(frequencies)
# Out:
# {'Line': 1539, 'trailing': 1530, 'spaces': 1530, 'column': 6, 'previous': 5, 'File': 3, 'end': 3, 'newline': 3, 'longer': 3, 'characters': 3, 'found': 3, 'next': 1, 'part': 1, 'multi': 1, 'block': 2, 'statement': 1, 'one': 1, 'directly': 1, 'contains': 1, 'multiple': 1, 'try': 1, 'catch': 1, 'finally': 1}

# %%
texts[5]
# Out:
# 'Utility classes should not have a public or default constructor.Utility classes should not have a public or default constructor.Missing package-info java file.Utility classes should not have a public or default constructor.Utility classes should not have a public or default constructor.Missing package-info java file.Utility classes should not have a public or default constructor.File contains tab characters (this is the first instance).Missing package-info java file.Utility classes should not have a public or default constructor.File does not end with a newline.Utility classes should not have a public or default constructor.Array brackets at illegal position.\'if\' construct must use \'{}\'s.\'\' is a magic number.\'+\' is not preceded with whitespace.Utility classes should not have a public or default constructor.Javadoc comment is placed in the wrong location.Unused import - java io.File.\' \' is followed by whitespace.Name \'readLines\' must match pattern \'^A-Za-zA-Z-*$\'.Missing package-info java file.Utility classes should not have a public or default constructor.Name \'elements\' must match pattern \'^A-Za-zA-Z-*$\'.Name \'I\' must match pattern \'^a-za-zA-Z-*$\'.Array brackets at illegal position.First sentence should end with a period.Expected @param tag for \'list\'.Array brackets at illegal position.\'for\' construct must use \'{}\'s.Name \'IndxNumEven\' must match pattern \'^a-za-zA-Z-*$\'.Array brackets at illegal position.Array brackets at illegal position.@return tag should be present and have description.Conditional logic can be removed.Conditional logic can be removed.Javadoc comment is placed in the wrong location.Javadoc comment is placed in the wrong location.Expression can be simplified.Expression can be simplified.Expression can be simplified.\'{\' at column should be on the previous line.Utility classes should not have a public or default constructor.Conditional logic can be removed.File does not end with a newline.Utility classes should not have a public or default constructor.Name \'readAwordnumber\' must match pattern \'^A-Za-zA-Z-*$\'.File does not end with a newline.Javadoc comment is placed in the wrong location.Utility classes should not have a public or default constructor.\'for\' is not followed by whitespace.Utility classes should not have a public or default constructor.\' \' is preceded with whitespace.\'/\' is not followed by whitespace.\'%\' is not followed by whitespace.Line is longer than characters (found ).\'%\' is not preceded with whitespace.Utility classes should not have a public or default constructor.Name \'NumberToParse\' must match pattern \'^a-za-zA-Z-*$\'.Missing package-info java file.First sentence should end with a period.Utility classes should not have a public or default constructor.Name \'PA_FileAverage\' must match pattern \'^A-Za-zA-Z-*$\'.First sentence should end with a period.File does not end with a newline.Utility classes should not have a public or default constructor.Name \'Lab_\' must match pattern \'^A-Za-zA-Z-*$\'.\'{\' at column should be on the previous line.\' \' is a magic number.Utility classes should not have a public or default constructor.File contains tab characters (this is the first instance).\' \' is a magic number.Name \'interest_year_one\' must match pattern \'^a-za-zA-Z-*$\'.Line has trailing spaces.Line has trailing spaces.Name \'interest_second_year\' must match pattern \'^a-za-zA-Z-*$\'.Name \'interest_third_year\' must match pattern \'^a-za-zA-Z-*$\'.File does not end with a newline.Utility classes should not have a public or default constructor.Missing package-info java file.Javadoc comment is placed in the wrong location.Name \'averageColumns\' must match pattern \'^A-Za-zA-Z-*$\'.Unused @param tag for \'variables\'.Unused @param tag for \'variable\'.Unused @param tag for \'variables\'.Unused @param tag for \'Scanner\'.Unused @param tag for \'array\'.Line is longer than characters (found ).Expected @param tag for \'args\'.Each variable d ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[5])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
# Process text
frequencies = wordcloud.process_text(texts[5])

print(frequencies)
# Out:
# {'Utility': 295, 'classes': 295, 'public': 295, 'default': 297, 'constructor': 295, 'Missing': 96, 'package': 94, 'info': 94, 'java': 105, 'File': 227, 'contains': 35, 'tab': 34, 'characters': 84, 'First': 163, 'instance': 34, 'end': 227, 'newline': 98, 'Array': 41, 'brackets': 40, 'illegal': 40, 'position': 40, "if'": 97, 'construct': 125, 'must': 458, 'use': 125, 's': 125, 'magic': 43, 'number': 43, 'preceded': 23, 'whitespace': 72, 'Javadoc': 149, 'comment': 148, 'placed': 146, 'wrong': 146, 'location': 146, 'Unused': 81, 'import': 11, 'io': 2, 'followed': 49, 'Name': 314, "readLines'": 1, 'match': 312, 'pattern': 312, 'zA': 621, 'Z': 313, "elements'": 1, "I'": 2, 'sentence': 129, 'period': 129, 'Expected': 92, 'param': 164, 'tag': 190, "list'": 1, "for'": 24, "IndxNumEven'": 1, 'return': 24, 'present': 24, 'description': 24, 'Conditional': 34, 'logic': 34, 'removed': 34, 'Expression': 26, 'simplified': 26, 'column': 40, 'previous': 33, 'Line': 112, "readAwordnumber'": 1, 'longer': 50, 'found': 50, "NumberToParse'": 1, "PA_FileAverage'": 1, "Lab_'": 2, "interest_year_one'": 1, 'trailing': 21, 'spaces': 21, "interest_second_year'": 1, "interest_third_year'": 1, "averageColumns'": 1, "variables'": 2, "variable'": 2, "Scanner'": 1, "array'": 9, "args'": 25, 'variable': 19, 'declaration': 11, 'statement': 13, "a'": 6, "stringAnalogy'": 1, "else'": 29, "threeInput'": 1, "ANSI_CYAN'": 3, "ANSI_PURPLE'": 3, "ANSI_GREEN'": 3, "pa'": 2, "stringchecker'": 1, "x'": 12, "y'": 12, "z'": 12, "VowTot'": 1, "PA_CompareArrays'": 2, "mul_tables'": 1, "PA_MultTable'": 1, "gradeTranslator'": 2, "PA__MultiplicationTable'": 1, "Number'": 1, "Product'": 1, "hello'": 2, "PA__Calculator'": 2, "range'": 1, "MAX_RAND_VAL'": 2, "Pa_Marquez'": 2, 'Parameter': 14, 'args': 4, 'final': 14, 'break': 4, "vowelCount'": 1, "IS_EQUAL_MASK'": 1, "x_bits'": 1, "got_second'": 5, "want_second'": 5, "TEST'": 2, "SUCCESS'": 4, "FAILURE'": 3, "PA_Methods'": 1, "double'": 15, "PA_Temperature'": 1, "string'": 6, "randomMethod'": 1, "rand'": 1, "Lab_b'": 4, "values'": 1, "Temp'": 4, "Num'": 1, "b'": 5, "C'": 4, "D'": 1, "F'": 4, "PA__CompareArrays'": 1, "arr'": 12, "ANSI_RESET'": 2, "DEBUGGING_YELLOW'": 2, "numberSplit'": 1, "length'": 5, 'private': 8, 'accessor': 8, "allTheSame'": 2, 'x': 3, "create'": 1, "Lab_a'": 6, "readTwostrings'": 1, "lab'": 2, "interest_rate'": 1, "account_balance'": 1, "years_to_calc'": 1, "letterGrade'": 1, 'cs': 2, "sequencereader'": 1, 'Z_': 3, 'w': 3, "PA__Vowels'": 1, "vowel_count'": 1, "Java_Elements'": 1, "MethodInput'": 3, "Input'": 4, "PA_LineNumbers'": 1, "accountBalanceAndInterest'": 1, "lineCounter'": 1, 'input': 2, "PA_StringComparison'": 1, "PA_LetterToNumberGrade'": 2, "PA__FileRead'": 1, "file_name'": 1, "col_sum'": 2, "col_value'": 2, "line_count'": 1, "line_columns'": 1, "col_avg'": 2, "PA_'": 5, "vowels'": 3, "not_valid'": 2, "order'": 2, "METHOD_STACK_INDEX'": 6, "DEFAULT_OUT'": 3, "DEFAULT_IN'": 3, "DAY_TOTAL_MINUTES'": 1, "arrayEquals'": 1, "firstArray'": 2, "secondArray'": 2, "random'": 1, "teachersExample'": 1, "PA_LetterGrade'": 1, "CS_PA'": 5, "process_sequence'": 1, "delimeted_sequence'": 1, "three'": 4, "got_third'": 2, "want_third'": 2, "EXCLUDE'": 1, "OFFSET'": 1, "NOT_FOUND'": 1, "DELIMETER'": 1, "multiple'": 1, "FH'": 1, "FM'": 1, "SH'": 1, "SM'": 1, "DH'": 1, "DM'": 1, "stringReverse'": 1, "str'": 5, "PA_VowelsInWord'": 1, 'Using': 3, 'form': 3, 'avoided': 3, 'util': 8, 'stream': 1, "PASS_STATUS'": 1, "FAIL_STATUS'": 1, "_gradeMap'": 1, "MAX_GRADE'": 1, "MIN_GRADE'": 1, "PA__CompareStrings'": 1, "Grade'": 2, "compareArrays'": 1, "inta'": 2, "intb'": 2, "stringTester'": 1, "PA__Temperature'": 1, "lettertonumber'": 1, "comparingNumbers'": 1, "PA_PhaseOfWater'": 1, 'least': 1, 'one': 2, "writeMethods'": 1, "int'": 2, "n'": 2, "Best_Friends'": 1, "TempType'": 1, "calculator'": 1, "PA__StatesOfWater'": 1, "PA_FileAverage_MatchExpectedOutput'": 1, "fileName'": 2, "line_counter'": 1, "INITAL_AMOUNT'": 1, "apply_interes ...

# %%
texts[6]
# Out:
# "Missing package-info java file.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.Missing a Javadoc comment.Line is longer than characters (found ).Missing package-info java file.Missing a Javadoc comment.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'+' is not preceded with whitespace.Missing package-info java file.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.Missing a Javadoc comment.'' is a magic number.Missing a Javadoc comment.'for' is not followed by whitespace.Missing a Javadoc comment.'for' is not followed by whitespace.Missing a Javadoc comment.'' is a magic number.'+' is not preceded with whitespace.Missing a Javadoc comment.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'+' is not preceded with whitespace.'' is a magic number.Missing package-info java file.@return tag should be present and have description.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.'-' is not preceded with whitespace.Missing package-info java file.Utility classes should not have a public or default constructor.Missing a Javadoc comment.Missing a Javadoc comment.Missing a Javadoc comment.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.Each variable declaration must be in its own statement.Line has trailing spaces.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.'' is a magic number.Missing package-info java file.Missing a Javadoc comment.Line has trailing spaces.Line has trailing spaces.First sentence should end with a period.Missing package-info java file.Missing a Javadoc comment.' ' is a magic number.'' is a magic number.Missing package-info java file.Missing a Javadoc comment.'' is a magic number.Line is longer than characters (found ).Missing package-info java file.Missing a Javadoc comment.File does not end with a newline.Line has trailing spaces.Missing package-info java file.Parameter z should be final.First sentence should end with a period.'if' is not followed by whitespace.Missing package-info java file.Unused import - java lang.Math.Missing a Javadoc comment.Missing a Javadoc comment.'' is a magic number.'' is a magic number.'' is a magic number.Missing package-info java file.Missing a Javadoc comment.'' is a magic number.Missing a Javadoc comment.Name 'ANSI_RESET' must match pattern '^a-za-zA-Z-*$'.Missing a Javadoc comment.'' is a magic number.'' is a magic number.Missing a Javadoc comment.Javadoc comment is placed in the wrong location.Missing a Javadoc comment.'' is a magic number.Missing a Javadoc comment.Line has trailing spaces.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.Missing package-info java file.Missing a Javadoc comment.File does not end with a newline.Missing package-info java file.Missing a Javadoc comment.Each variable declaration must be in its own statement.'' is a magic number.'' is a magic number.Missing package-info java file.Missing a Javadoc comment.File does not end with a newline.Missing a Javadoc comment.Missing a Javadoc comment.Line has trailing spaces.' ' is not fol ...

# %%
#Create the wordcloud object
wordcloud = WordCloud(collocations= COLLOCATIONS,
                        background_color="white",
                        collocation_threshold = COLLOCATION,
                        max_words = MAX_WORDS,
                        relative_scaling = 1).generate(texts[6])
#plot
plt.figure(figsize=(7,5), dpi=100)
plt.imshow(wordcloud, interpolation='bilInear')
plt.axis('off')

plt.show()

# %%
 # Process text
frequencies = wordcloud.process_text(texts[6])

print(frequencies)
# Out:
# {'Missing': 768, 'package': 274, 'info': 272, 'java': 297, 'file': 338, 'Javadoc': 515, 'comment': 515, 'magic': 637, 'number': 637, 'Line': 124, 'longer': 52, 'characters': 67, 'found': 52, 'preceded': 45, 'whitespace': 82, "for'": 9, 'followed': 37, 'return': 13, 'tag': 17, 'present': 13, 'description': 13, 'Utility': 31, 'classes': 31, 'public': 31, 'default': 31, 'constructor': 31, 'variable': 18, 'declaration': 9, 'must': 23, 'statement': 26, 'trailing': 50, 'spaces': 50, 'First': 47, 'sentence': 32, 'end': 83, 'period': 32, 'newline': 51, 'Parameter': 20, 'z': 5, 'final': 20, "if'": 9, 'Unused': 8, 'import': 23, 'lang': 9, 'Math': 7, 'Name': 2, "ANSI_RESET'": 1, 'match': 2, 'pattern': 2, 'za': 4, 'placed': 19, 'wrong': 19, 'location': 19, 'Using': 13, 'form': 13, 'avoided': 13, 'util': 13, 'Conditional': 2, 'logic': 2, 'removed': 2, 'Array': 3, 'brackets': 1, 'illegal': 1, 'position': 1, "input'": 6, 'private': 9, 'accessor': 9, 'methods': 9, 'contains': 30, 'tab': 15, 'instance': 15, 'io': 3, 'x': 1, 'construct': 3, 'use': 3, 's': 3, 'Expected': 1, 'param': 1, "args'": 1, 'values': 2, "tempFormat'": 1, 'column': 21, 'next': 15, 'part': 15, 'multi': 15, 'block': 31, 'one': 15, 'directly': 15, 'multiple': 15, 'try': 15, 'catch': 15, 'finally': 15, "else'": 3, 'abs': 1, 'previous': 6, 'args': 9, "FAILURE'": 2, 'Redundant': 2, "gradeMap'": 1, 'InputMismatchException': 1, "while'": 3, 'y': 1, 'intsInList': 1, "time'": 2, 'hides': 4, 'field': 4, 'Unknown': 3, "date'": 2, 'new': 1, "first'": 1, "second'": 1, 'Definition': 2, 'equals': 1, 'without': 1, 'corresponding': 1, 'hashCode': 1, 'FirstNum': 1, 'charArray': 1, "Author'": 1, 'Empty': 2, 'Avoid': 1, 'nested': 1}
