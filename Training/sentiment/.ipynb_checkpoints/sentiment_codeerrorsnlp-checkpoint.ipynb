# %% [markdown]
# https://medium.com/@AmyGrabNGoInfo/sentiment-analysis-hugging-face-zero-shot-model-vs-flair-pre-trained-model-57047452225d

# %% [markdown]
# ## Load the data

# %%
# !pip install pandas numpy
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv("/content/sample_data/tweet_AAPL.csv")
df = pd.read_csv("./theCleanedTweets.csv")
# Out:
# /tmp/ipykernel_28259/2255055844.py:2: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./theCleanedTweets.csv")

# %%
df
# Out:
#               date      time  \
# 0       2021/12/30  18:55:50
# 1       2021/12/30  18:54:23
# 2       2021/12/30  18:44:16
# 3       2021/12/30  18:38:04
# 4       2021/12/30  18:26:33
# ...            ...       ...
# 116170  2020/12/24  20:36:07
# 116171  2020/12/24  20:30:33
# 116172  2020/12/24  20:24:17
# 116173  2020/12/24  20:00:51
# 116174  2020/12/24  19:31:10
#
#                                                     tweet  retweets_count  \
# 0                                        $AAPL dirty ????             0.0
# 1       $aapl big PUT order placed today:  somebody bo...             0.0
# 2                               @MrStockBot $aapl options             0.0
# 3       $AAPL No sell off tomorrow!!!! Why create a ta...             0.0
# 4       @leadlagreport The entire crypto market is not...             1.0
# ...                                                   ...             ...
# 116170  Apple had a $350B market cap when Tim Cook bec...             2.0
# 116171                   @erikaash13 $AAPL $AMZN or $GOOG             0.0
# 116172                    @Stocktwits Maybe a poll? $aapl             0.0
# 116173  My son: ?€?Dad I want an iPad for Christmas.?€...             0.0
# 116174  @AdamSinger Does $AAPL have enough market cap ...             0.0
#
#        likes_count LEN                                            tweetV2  \
# 0                0   1                                         aapl dirty
# 1                0   1  aapl big put order placed today somebody bough...
# 2                1   1                                       aapl options
# 3                0   1  aapl no sell off tomorrow why create a tax bur...
# 4                4   1  the entire crypto market is not even the size ...
# ...            ...  ..                                                ...
# 116170          56   3  apple had a b market cap when tim cook became ...
# 116171           2   3                                  aapl amzn or goog
# 116172           0   1                                  maybe a poll aapl
# 116173           1   1  my son dad i want an ipad for christmas me im ...
# 116174           4   1  does aapl have enough market cap to tender an ...
#
#                                          tokenized_tweets  \
# 0                                       ['aapl', 'dirty']
# 1       ['aapl', 'big', 'put', 'order', 'placed', 'tod...
# 2                                     ['aapl', 'options']
# 3       ['aapl', 'no', 'sell', 'off', 'tomorrow', 'why...
# 4       ['the', 'entire', 'crypto', 'market', 'is', 'n...
# ...                                                   ...
# 116170  ['apple', 'had', 'a', 'b', 'market', 'cap', 'w...
# 116171                     ['aapl', 'amzn', 'or', 'goog']
# 116172                     ['maybe', 'a', 'poll', 'aapl']
# 116173  ['my', 'son', 'dad', 'i', 'want', 'an', 'ipad'...
# 116174  ['does', 'aapl', 'have', 'enough', 'market', '...
#
#                                             lemmon_tweets
# 0                                              aapl dirty
# 1       aapl big put order placed today somebody bough...
# 2                                             aapl option
# 3       aapl no sell off tomorrow why create a tax bur...
# 4       the entire crypto market is not even the size ...
# ...                                                   ...
# 116170  apple had a b market cap when tim cook became ...
# 116171                                  aapl amzn or goog
# 116172                                  maybe a poll aapl
# 116173  my son dad i want an ipad for christmas me im ...
# 116174  doe aapl have enough market cap to tender an o...
#
# [116175 rows x 9 columns]

# %%
df = df[['date','tweetV2']]
df
# Out:
#               date                                            tweetV2
# 0       2021/12/30                                         aapl dirty
# 1       2021/12/30  aapl big put order placed today somebody bough...
# 2       2021/12/30                                       aapl options
# 3       2021/12/30  aapl no sell off tomorrow why create a tax bur...
# 4       2021/12/30  the entire crypto market is not even the size ...
# ...            ...                                                ...
# 116170  2020/12/24  apple had a b market cap when tim cook became ...
# 116171  2020/12/24                                  aapl amzn or goog
# 116172  2020/12/24                                  maybe a poll aapl
# 116173  2020/12/24  my son dad i want an ipad for christmas me im ...
# 116174  2020/12/24  does aapl have enough market cap to tender an ...
#
# [116175 rows x 2 columns]

# %%
df = df.reindex(index = df.index[::-1]).reset_index(drop=True)
df
# Out:
#               date                                            tweetV2
# 0       2020/12/24  does aapl have enough market cap to tender an ...
# 1       2020/12/24  my son dad i want an ipad for christmas me im ...
# 2       2020/12/24                                  maybe a poll aapl
# 3       2020/12/24                                  aapl amzn or goog
# 4       2020/12/24  apple had a b market cap when tim cook became ...
# ...            ...                                                ...
# 116170  2021/12/30  the entire crypto market is not even the size ...
# 116171  2021/12/30  aapl no sell off tomorrow why create a tax bur...
# 116172  2021/12/30                                       aapl options
# 116173  2021/12/30  aapl big put order placed today somebody bough...
# 116174  2021/12/30                                         aapl dirty
#
# [116175 rows x 2 columns]

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
# Define pipeline
classifier = pipeline(task="zero-shot-classification",
                      model="facebook/bart-large-mnli",
                      device='cpu')

# %%
# !pip3 uninstall torch torchvision torchaudio -y

# %%
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/rocm5.7
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/rocm5.6

# %%
#
small_df = df.sample(frac=.05, random_state=42)
print(small_df.shape)
print(small_df.head())
# Out:
# (5809, 2)
#             date                                            tweetV2
# 37451   2021/5/3                       do you have pt for aapl gary
# 38591   2021/5/7  this is amazing a good example of where the ba...
# 16511  2021/2/18     aapl is still my most profitable trade to date
# 24840  2021/3/17  too many calls after er beat so they fabricate...
# 34376  2021/4/28  aapl closed today at if you bought share of aa...

# %%
df['tweetV2'].map(type) != str
df = df[df['tweetV2'].apply(lambda x: isinstance(x, str))]

# %% [markdown]
# ### Neutral

# %%
from tqdm import tqdm
# Put reviews in a list
#sequences = small_df.head(20)['tweetV2'].to_list()

sequences = df['tweetV2'].to_list()

candidate_labels = ["positive", "neutral", "negative"]

hypothesis_template = "The sentiment of this review is {}."

predictions = []

for sequence in tqdm(sequences, desc="Classifying Sentiments"):
    result = classifier(sequence, candidate_labels, hypothesis_template=hypothesis_template)
    predictions.append(result)

hf_prediction = pd.DataFrame(predictions)
# Out:
# Classifying Sentiments:   6%|▌         | 6970/116174 [1:04:46<19:13:01,  1.58it/s]

# %%
# import concurrent.futures
# from tqdm import tqdm

# sequences = df['tweetV2'].to_list()
# candidate_labels = ["positive", "neutral", "negative"]
# hypothesis_template = "The sentiment of this review is {}."

# def classifySentiment(sequence):
#     return classifier(sequence, candidate_labels, hypothesis_template=hypothesis_template)

# num_threads = 50

# sequence_chunks = [sequences[i:i + num_threads] for i in range(0, len(sequences), num_threads)]

# predictions = []

# with concurrent.futures.ThreadPoolExecutor(max_workers=num_threads) as executor:
#     for chunk in tqdm(sequence_chunks, desc="Classifying Sentiments"):
#         results = list(executor.map(classifySentiment, chunk))
#         predictions.extend(results)

# hf_prediction = pd.DataFrame(predictions)

# %%
# Take a look at the data
hf_prediction.head(10)

# %%
hf_prediction.iloc[2]

# %%
hf_prediction.iloc[2].sequence

# %% [markdown]
# ### TO DO: We need to sort the column "labels" and "scores" to have the labels "positive, neutral, and negative" matching the scores.
#
# ### If possible, have three columns, "positive", "neutral", and "negative"

# %%
labelOreo = ['positive', 'neutral', 'negative']

def labelSort(row):
    labels, scores = row['labels'].tolist(), row['scores']
    
    label_index = {label: labelOreo.index(label) for label in labels}
    
    sorted_labels = sorted(labels, key=lambda x: label_index[x])
    
    sorted_scores = [scores[labels.index(label)] for label in sorted_labels]
    
    return sorted_labels, sorted_scores

hf_prediction[['labels','scores']] = hf_prediction.apply(labelSort, axis=1, result_type='expand')

# %%
hf_prediction

# %%
hf_prediction.to_csv("./20HoursOfPain.csv", index=False)
